# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import math
import datetime
import random, string
import faker
import plotly.figure_factory as ff
import openpyxl

# from geopy.geocoders import Nominatim

# %%
regions_df = pd.read_csv('./region.csv')

# названия пипец херовые у этой таблицы
regions_df
# Out:
#               name  type     name_with_type   federal_district       kladr_id  \
# 0           Адыгея  Респ        Респ Адыгея              Южный   100000000000
# 1     Башкортостан  Респ  Респ Башкортостан        Приволжский   200000000000
# 2          Бурятия  Респ       Респ Бурятия    Дальневосточный   300000000000
# 3            Алтай  Респ         Респ Алтай          Сибирский   400000000000
# 4         Дагестан  Респ      Респ Дагестан  Северо-Кавказский   500000000000
# ..             ...   ...                ...                ...            ...
# 81       Чукотский    АО       Чукотский АО    Дальневосточный  8700000000000
# 82  Ямало-Ненецкий    АО  Ямало-Ненецкий АО          Уральский  8900000000000
# 83            Крым  Респ          Респ Крым              Южный  9100000000000
# 84     Севастополь     г      г Севастополь              Южный  9200000000000
# 85        Байконур     г         г Байконур                NaN  9900000000000
#
# ...

# %%
# geolocator = Nominatim(user_agent="geoapiExercises")
#
# # Latitude & Longitude input
# Latitude = "25.594095"
# Longitude = "85.137566"
#
# location = geolocator.reverse(Latitude+","+Longitude)
#
# # Display
# print(location)

# %%
# import reverse_geocoder as rg
#
# coordinates = (55.751244, 37.618423),(62.0313335,129.7017859),(56.7429074,37.1116399)
#
# results = rg.search(coordinates) # default mode = 2
#
# print(results)

# %%
# 1я запись - рф
salary_df = pd.read_excel('./region-salary.xlsx', sheet_name="prepared")

salary_df['region'] = salary_df['region'].str.strip()

country_salary, regions_salary = salary_df[0:1], salary_df[1:-1]

country_salary
# Out:
#                  region  2019-01-01 00:00:00  2019-02-01 00:00:00  \
# 0  Российская Федерация              42263.2              43062.4
#
#    2019-03-01 00:00:00  2019-04-01 00:00:00  2019-05-01 00:00:00  \
# 0              46324.2              48029.8              47926.2
#
#    2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00  \
# 0              49347.9              46509.4              44961.3
#
#    2019-09-01 00:00:00  ...  2022-03-01 00:00:00  2022-04-01 00:00:00  \
# 0              45540.9  ...              66757.4              62268.9
#
#    2022-05-01 00:00:00  2022-06-01 00:00:00  2022-07-01 00:00:00  \
# 0              62456.8              66572.2              62199.7
#
#    2022-08-01 00:00:00  2022-09-01 00:00:00  2022-10-01 00:00:00  \
# 0              59906.7              61878.7                62470
#
#    2022-11-01 00:00:00  2022-12-01 00:00:00
# 0              63060.2              88468.3
#
# [1 rows x 49 columns]

# %%
regions_salary.head(100)
# Out:
#                    region  2019-01-01 00:00:00  2019-02-01 00:00:00  \
# 1    Белгородская область              31858.0              30679.9
# 2        Брянская область              26826.3              26752.4
# 3    Владимирская область              31220.1              29983.7
# 4     Воронежская область              30413.9              30766.5
# 5      Ивановская область              24711.1              24874.7
# ..                    ...                  ...                  ...
# 77       Хабаровский край              46214.1              45852.2
# 78       Амурская область              42594.1              42297.6
# 79    Магаданская область              79876.7              81942.3
# 80    Сахалинская область              84593.1              79555.3
# 81  Еврейская авт.область              38016.7              39053.7
#
#     2019-03-01 00:00:00  2019-04-01 00:00:00  2019-05-01 00:00:00  \
# 1               32926.5              33617.2              33899.1
# ...

# %%
citiesData = pd.read_csv('./koord_russia.csv', delimiter=';', encoding='windows-1251')

citiesData['Регион'] = citiesData['Регион'].str.strip()

citiesData = citiesData.merge(salary_df, left_on=['Регион'], right_on=['region'], how="inner")

# citiesData['region']
# citiesData['region'] == np.nan
# citiesData['region'].isnull().sum()

citiesData
# Out:
#                 Город                Регион Федеральный округ        lat  \
# 0            Абдулино  Оренбургская область       Приволжский  53,677839
# 1          Бугуруслан  Оренбургская область       Приволжский    53,6523
# 2             Бузулук  Оренбургская область       Приволжский  52,788116
# 3            Кувандык  Оренбургская область       Приволжский  51,478483
# 4          Медногорск  Оренбургская область       Приволжский  51,403794
# ..                ...                   ...               ...        ...
# 874      Спас-Клепики     Рязанская область       Центральный  55,131038
# 875  Спасск-Рязанский     Рязанская область       Центральный  54,407072
# 876              Шацк     Рязанская область       Центральный  51,496839
# 877           Магадан   Магаданская область   Дальневосточный  59,568164
# 878           Сусуман   Магаданская область   Дальневосточный  62,780464
#
#             lng                region  2019-01-01 00:00:00  \
# ...

# %%
inflation_total_df = pd.read_csv('./inflation_total.csv')

inflation_total_df = inflation_total_df.loc[(inflation_total_df['Год'] >= 2019) & (inflation_total_df['Год'] <= 2022)]

inflation_total_df
# Out:
#     Год   Янв   Фев    Мар    Апр    Май    Июн    Июл    Авг    Сен    Окт  \
# 1  2022  8.74  9.16  16.70  17.83  17.11  15.90  15.09  14.30  13.67  12.63
# 2  2021  5.19  5.67   5.78   5.52   6.01   6.51   6.47   6.69   7.41   8.14
# 3  2020  2.42  2.31   2.55   3.10   3.03   3.21   3.37   3.57   3.67   3.98
# 4  2019  5.00  5.24   5.27   5.17   5.13   4.66   4.59   4.33   3.99   3.77
#
#      Ноя    Дек  Всего
# 1  11.97  11.92  11.92
# 2   8.40   8.39   8.39
# 3   4.42   4.91   4.91
# 4   3.54   3.05   3.05

# %%
inflation_by_month_df = pd.read_csv('./inflation_total.csv')

inflation_by_month_df = inflation_by_month_df.loc[(inflation_by_month_df['Год'] >= 2019) & (inflation_by_month_df['Год'] <= 2022)]

inflation_by_month_df
# Out:
#     Год   Янв   Фев    Мар    Апр    Май    Июн    Июл    Авг    Сен    Окт  \
# 1  2022  8.74  9.16  16.70  17.83  17.11  15.90  15.09  14.30  13.67  12.63
# 2  2021  5.19  5.67   5.78   5.52   6.01   6.51   6.47   6.69   7.41   8.14
# 3  2020  2.42  2.31   2.55   3.10   3.03   3.21   3.37   3.57   3.67   3.98
# 4  2019  5.00  5.24   5.27   5.17   5.13   4.66   4.59   4.33   3.99   3.77
#
#      Ноя    Дек  Всего
# 1  11.97  11.92  11.92
# 2   8.40   8.39   8.39
# 3   4.42   4.91   4.91
# 4   3.54   3.05   3.05

# %%
bank_key_rate = pd.read_csv('./bank_key_rate.csv')

bank_key_rate['date'] = pd.to_datetime(bank_key_rate['date'], format="%d.%m.%Y")

bank_key_rate = bank_key_rate.loc[(bank_key_rate['date'] >= datetime.datetime(2019, 1, 1)) & (bank_key_rate['date'] <= datetime.datetime(2022, 12, 31))]

bank_key_rate
# Out:
#            date  value
# 1310 2019-01-09   7.75
# 1311 2019-01-10   7.75
# 1312 2019-01-11   7.75
# 1313 2019-01-14   7.75
# 1314 2019-01-15   7.75
# ...         ...    ...
# 2310 2022-12-26   7.50
# 2311 2022-12-27   7.50
# 2312 2022-12-28   7.50
# 2313 2022-12-29   7.50
# 2314 2022-12-30   7.50
#
# [1005 rows x 2 columns]

# %%
usd_rub_df = pd.read_csv('./usb-rub.csv')

usd_rub_df = usd_rub_df[['Date', 'Adj Close']].rename(columns={"Date": "date", "Adj Close": "value"})

usd_rub_df
# Out:
#            date      value
# 0    2021-11-01  70.823402
# 1    2021-11-02  71.579903
# 2    2021-11-03  71.605400
# 3    2021-11-04  71.695602
# 4    2021-11-05  71.405998
# ..          ...        ...
# 366  2023-03-28  76.500000
# 367  2023-03-29  76.525002
# 368  2023-03-30  77.290001
# 369  2023-03-31  77.239998
# 370  2023-03-31  77.975998
#
# [371 rows x 2 columns]

# %%
imoex_df = pd.read_csv('./imoex.csv')

imoex_df = imoex_df[['Date', 'Adj Close']].rename(columns={"Date": "date", "Adj Close": "value"})

imoex_df
# Out:
#            date        value
# 0    2021-11-01  4221.490234
# 1    2021-11-02  4207.529785
# 2    2021-11-03  4184.870117
# 3    2021-11-05  4174.759766
# 4    2021-11-08  4218.270020
# ..          ...          ...
# 333  2023-03-24  2391.530029
# 334  2023-03-27  2440.679932
# 335  2023-03-28  2442.189941
# 336  2023-03-29  2460.870117
# 337  2023-03-30  2465.929932
#
# [338 rows x 2 columns]

# %%
# fetch("https://wordstat.yandex.ru/stat/history", {
#     "referrer": "https://wordstat.yandex.ru/",
#     "referrerPolicy": "strict-origin-when-cross-origin",
#     "body": "db=&filter=all&map=world&page=1&page_type=history&period=monthly&regions=&sort=cnt&type=list&words=%D0%B4%D1%83%D1%85%D0%B8+%D0%B8+%D1%82%D1%83%D0%B0%D0%BB%D0%B5%D1%82%D0%BD%D0%B0%D1%8F+%D0%B2%D0%BE%D0%B4%D0%B0",
#     "method": "POST",
#     "mode": "cors",
#     "credentials": "include"
# });

wordstats_cosmetics = pd.read_json('./wordstat-cosmetics.json')

wordstats_cosmetics = wordstats_cosmetics.drop_duplicates(subset='date')

wordstats_cosmetics = wordstats_cosmetics.sort_values('date')\
    .loc[wordstats_cosmetics['totalCount'] != 0]\
    .loc[wordstats_cosmetics['date'] >= '2021-10-01']\
    .loc[wordstats_cosmetics['date'] <= '2022-11-30']

wordstats_cosmetics['totalCount'] = (wordstats_cosmetics['totalCount']-wordstats_cosmetics['totalCount'].min())/(wordstats_cosmetics['totalCount'].max()-wordstats_cosmetics['totalCount'].min())

wordstats_cosmetics = wordstats_cosmetics.set_index('date')

px.line(wordstats_cosmetics, y='totalCount')
# Out:
# <div>                            <div id="12ded3c5-4654-4a14-a34d-63a6477cdcef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12ded3c5-4654-4a14-a34d-63a6477cdcef")) {                    Plotly.newPlot(                        "12ded3c5-4654-4a14-a34d-63a6477cdcef",                        [{"hovertemplate":"date=%{x}<br>totalCount=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-0
# ...

# %%
wordstats_cosmetics_google = pd.read_csv('./wordstat-cosmetics-google-category.csv', parse_dates=['Неделя'])
# wordstats_cosmetics_google = pd.read_csv('./wordstat-cosmetics-google-category-water.csv')

wordstats_cosmetics_google = wordstats_cosmetics_google.drop_duplicates(subset='Неделя')

wordstats_cosmetics_google = wordstats_cosmetics_google\
    .loc[wordstats_cosmetics_google['Неделя'] >= '2021-10-01'] \
    .loc[wordstats_cosmetics_google['Неделя'] <= '2022-11-30']

wordstats_cosmetics_google['Баллы'] = wordstats_cosmetics_google['Баллы'].rolling(window=5, center=True).mean()

wordstats_cosmetics_google['Баллы'] = (wordstats_cosmetics_google['Баллы']-wordstats_cosmetics_google['Баллы'].min())/(wordstats_cosmetics_google['Баллы'].max()-wordstats_cosmetics_google['Баллы'].min())

wordstats_cosmetics_google = wordstats_cosmetics_google.set_index('Неделя')

# px.line(wordstats_cosmetics_google, y='Баллы')

# %%
fig = px.line(wordstats_cosmetics_google, y="Баллы")

fig.add_scatter(x=wordstats_cosmetics.index, y=wordstats_cosmetics['totalCount']) # Not what is desired - need a line

fig.show()
# Out:
# <div>                            <div id="a9cb9a9e-8a10-40dc-a116-fad1b3d7638a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9cb9a9e-8a10-40dc-a116-fad1b3d7638a")) {                    Plotly.newPlot(                        "a9cb9a9e-8a10-40dc-a116-fad1b3d7638a",                        [{"hovertemplate":"\u041d\u0435\u0434\u0435\u043b\u044f=%{x}<br>\u0411\u0430\u043b\u043b\u044b=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-10-03T00:00:00","2021-10-10T00:00:00","2021-10-17T00:00:00","2021-10-24T00:00:00","2021-10-31T00:00:00","2021-11-07T00:00:00","2021-11-14T00:00:00","2021-11-21T00:00:00","2021-11-28T00:00:00"
# ...

# %%
wordstats_cosmetics_spline = wordstats_cosmetics.resample('D').interpolate('time', order=2)
wordstats_cosmetics_google_spline = wordstats_cosmetics_google.resample('D').interpolate('time', order=2)

fig2 = px.line(wordstats_cosmetics_google_spline, y="Баллы")

fig2.add_scatter(x=wordstats_cosmetics_spline.index, y=wordstats_cosmetics_spline['totalCount'], name='yandex')

fig2.show()
# Out:
# <div>                            <div id="306e8634-8be9-40c3-a65c-e516e1730e9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("306e8634-8be9-40c3-a65c-e516e1730e9b")) {                    Plotly.newPlot(                        "306e8634-8be9-40c3-a65c-e516e1730e9b",                        [{"hovertemplate":"\u041d\u0435\u0434\u0435\u043b\u044f=%{x}<br>\u0411\u0430\u043b\u043b\u044b=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-09T00:00:00","2021-10-10T00:00:00","2021-10-11T00:00:00"
# ...

# %%
google_popularity = 0.35
yandex_popularity = 0.65

wordstats_cosmetics_spline['mean'] = wordstats_cosmetics_spline['totalCount'] * yandex_popularity + wordstats_cosmetics_google_spline['Баллы'] * google_popularity

fig3 = px.line(wordstats_cosmetics_google_spline, y="Баллы")

fig3.add_scatter(x=wordstats_cosmetics_spline.index, y=wordstats_cosmetics_spline['totalCount'], name='yandex')

fig3.add_scatter(x=wordstats_cosmetics_spline.index, y=wordstats_cosmetics_spline['mean'], name='mean')

fig3.show()
# Out:
# <div>                            <div id="d8d66ddc-fb09-49e7-a9f2-917ea5cd6f42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8d66ddc-fb09-49e7-a9f2-917ea5cd6f42")) {                    Plotly.newPlot(                        "d8d66ddc-fb09-49e7-a9f2-917ea5cd6f42",                        [{"hovertemplate":"\u041d\u0435\u0434\u0435\u043b\u044f=%{x}<br>\u0411\u0430\u043b\u043b\u044b=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-09T00:00:00","2021-10-10T00:00:00","2021-10-11T00:00:00"
# ...

# %%
import os
import glob

path = os.getcwd()

yandex_json_files = glob.glob(os.path.join(path, "yandex-wordstats/*.json"))
google_csv_files = glob.glob(os.path.join(path, "google-trends/*.csv"))

yandex_data = []
google_data = []

start_date = '2021-10-15'
end_date = '2022-11-30'

def prepare_title(f):
    head, tail = f.split('.')
    return os.path.basename(head)

def prepare_data(title, df):
    df = df.drop_duplicates(subset='date')

    df = df.sort_values('date') \
        .loc[df['totalCount'] != 0] \
        .loc[df['date'] >= start_date] \
        .loc[df['date'] <= end_date]

    df['totalCount'] = (df['totalCount']-df['totalCount'].min())/(df['totalCount'].max()-df['totalCount'].min())

    df = df[['date', 'totalCount']]

    df = df.set_index('date')

    return { 'title': title, 'df': df }


for f in yandex_json_files:
    df = pd.read_json(f)
    yandex_data.append(prepare_data(prepare_title(f), df))

import wordstats

for f in google_csv_files:
    title = prepare_title(f)
    json_str = wordstats.google_wordstats_json(title)

    df = pd.read_json(json_str)
    df['value'] = df['value'].rolling(window=5, center=True).mean()
    df['totalCount'] = df['value']
    google_data.append(prepare_data(title, df))

google_data[2]['df']

# %%
google_popularity = 0.35
yandex_popularity = 0.65

dfs = []

for data in yandex_data:
    title, yandex_df = data['title'], data['df']

    g_data = [x for x in google_data if x['title'] == title][0]

    google_df = g_data['df']

    yandex_df_spline = yandex_df.resample('D').interpolate('time', order=2)

    google_df_spline = google_df.resample('D').interpolate('time', order=2)

    df = pd.DataFrame({
        'google': google_df_spline['totalCount'],
        'yandex': yandex_df_spline['totalCount'],
        'y0.65/g0.35': yandex_df_spline['totalCount'] * yandex_popularity + google_df_spline['totalCount'] * google_popularity,
    })

    dfs.append({'title': title, 'df': df})

# %%
for df in dfs[5:6]:
    px.line(df['df'], title=df['title']).show()
